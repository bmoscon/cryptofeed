# %%
from cryptofeed.rest import Rest
rest = Rest(sandbox=True)

# %%
fills = rest.coinbase.fills('BTC-USD')
fills

# %%
orders = rest.coinbase.get_orders({'status': ['pending']})
orders

# %%
trades = rest.coinbase.execute_trades([{"size": "0.01", "price": "0.100", "side": "buy", "product_id": "BTC-USD"}])

# %%
rest.coinbase.get_accounts()

# %%
rest.coinbase.get_account('2c9f0fd4-68e6-4c22-af8f-20779382e4d1')

# %%
rest.coinbase.get_account_history('2c9f0fd4-68e6-4c22-af8f-20779382e4d1')

# %%
rest.coinbase.get_holds('2c9f0fd4-68e6-4c22-af8f-20779382e4d1')

# %%
rest.coinbase.list_payment_methods()

# %%
rest.coinbase.list_coinbase_accounts()

# %%
deposit = {
    "amount": 10.00,
    "currency": "GBP",
    "payment_method_id": "b22911ee-ef35-5c97-bdd4-aef3f65618d9"
}

rest.coinbase.deposit_funds(deposit)

# %%
withdrawal = {
    "amount": 10.00,
    "currency": "GBP",
    "payment_method_id": "b22911ee-ef35-5c97-bdd4-aef3f65618d9"
}

rest.coinbase.withdrawal_funds(withdrawal)

# %%
deposit = {
    "amount": 10.00,
    "currency": "BTC",
    "coinbase_account_id": '95671473-4dda-5264-a654-fc6923e8a334',
}

rest.coinbase.deposit_coinbase(deposit)

# %%
withdrawal = {
    "amount": 10.00,
    "currency": "BTC",
    "coinbase_account_id": '95671473-4dda-5264-a654-fc6923e8a334',
}

rest.coinbase.withdrawal_coinbase(withdrawal)
